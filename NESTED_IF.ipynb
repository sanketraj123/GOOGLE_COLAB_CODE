# %% [markdown]
# <a href="https://colab.research.google.com/github/sanketraj123/GOOGLE_COLAB_CODE/blob/main/NESTED_IF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nested if example in Python

age = int(input("Enter the age:"))
citizen = True

if age >= 18:

    if citizen == True:
        print("Eligible to vote")

    else:
        print("Not a citizen")

else:
    print("Under 18")

# %% [markdown]
# <a href="https://colab.research.google.com/github/sanketraj123/GOOGLE_COLAB_CODE/blob/main/IF_ELSE_STATEMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Proper syntax of if else in Python
print("Enter your age")
age = int(input())

if age >= 18:
    print("You can vote")

else:
    print("You cannot vote")
# Out:
# Enter your age
# 18
# You can vote

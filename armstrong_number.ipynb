# %% [markdown]
# <a href="https://colab.research.google.com/github/sanketraj123/GOOGLE_COLAB_CODE/blob/main/armstrong_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("enter the number:"))
temp=n
sum=0
while (n>0):
  r=n%10
  sum=sum+(r**3)
  n=n//10

if (temp==sum):
  print("number is armstrong")
else:
  print("number is not armstrong")
# Out:
# enter the number:153
# number is armstrong

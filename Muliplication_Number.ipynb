# %% [markdown]
# <a href="https://colab.research.google.com/github/sanketraj123/GOOGLE_COLAB_CODE/blob/main/Muliplication_Number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=int(input("enter the number:"))
print("multiplication of number:",num)
for i in range(1,10+1):
  print(num,"x",i,"=",num*i)
# Out:
# enter the number:6
# multiplication of number: 6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
